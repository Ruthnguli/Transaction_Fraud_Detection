# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (roc_auc_score, classification_report, 
                              confusion_matrix, RocCurveDisplay, 
                              PrecisionRecallDisplay)
from imblearn.over_sampling import SMOTE
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
# Load data
df = pd.read_csv('../data/Synthetic_Financial_datasets_log.csv')
df = df.dropna().drop(columns=['nameOrig', 'nameDest'])
df['type'] = df['type'].astype('category').cat.codes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load data
# ----> 2 df = pd.read_csv('../data/Synthetic_Financial_datasets_log.csv')
#       3 df = df.dropna().drop(columns=['nameOrig', 'nameDest'])
#       4 df['type'] = df['type'].astype('category').cat.codes
#
# NameError: name 'pd' is not defined

# %%
print(f"Shape: {df.shape}")
print(f"Fraud rate: {df['isFraud'].mean()*100:.3f}%")
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(f"Shape: {df.shape}")
#       2 print(f"Fraud rate: {df['isFraud'].mean()*100:.3f}%")
#       3 df.head()
#
# NameError: name 'df' is not defined
